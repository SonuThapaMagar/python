# %%
a=5
print(type(a))

b=float(a)
print(b)
print(type(b))

#Converting into comples from float
c=complex(b)
print(c)
print(type(c))

#Converting into string
d=str(a)
print(a)
print("Ater converting into string",d)
print("Type of data after casting:",type(d))

#Converting into integer from float
e=int(b)
print("Before converting into int:",b)
print("Ater converting into int",e)
print("Type of data after casting:",type(e))


#Converting into complex from string
str="Hello"
print("String before converting into complex:",str)
c=complex(b)
print(c)
print(type(c))
# Out:
# <class 'int'>
# 5.0
# <class 'float'>
# (5+0j)
# <class 'complex'>
# 5
# Ater converting into string 5
# Type of data after casting: <class 'str'>
# Before converting into int: 5.0
# Ater converting into int 5
# Type of data after casting: <class 'int'>

# %%
name=input("Enter your name: ")
age=int(input("Enter your age: "))
school=input("Enter your school name: ")
subject=input("ENter your favorite subject: ")
print(type(name),type(age),type(school),type(subject))
print(f"Your Name: {name} Age:{age} School: {school} Subject: {subject}")
# Out:
# <class 'str'> <class 'int'> <class 'str'> <class 'str'>
# Your Name: Sonu Thapa Magar Age:23 School: Virinchi College Subject: English

# %%
list1=[1,2,3,4,5,6,True,"apple"]
print(list1[0])
print("Slicing",list1[:5])
print(list1[-4:-1])
# Out:
# 1
# Slicing [1, 2, 3, 4, 5]
# [5, 6, True]

# %%
list1[0]=5
print(list1)
# Out:
# [5, 2, 3, 4, 5, 6, True, 'apple']

# %%
list1
list1[0:2]=[11,22]
list1[4:6]=[False,"banana"]
list1
# Out:
# [11, 22, 5, 6, False, 'banana']

# %%
#Adding
a=[1,2,3,4,5]
b=["A","B"]
s={"C","D"}
t=(123,321)

print("Before appending:",a)
a.append(6)
print("Adding using append()",a)
a.insert(2,"Hi")
print("After inserting",a)
a.extend(b)
print("List a:",a )
print("List b:",b)
# Out:
# Before appending: [1, 2, 3, 4, 5]
# Adding using append() [1, 2, 3, 4, 5, 6]
# After inserting [1, 2, 'Hi', 3, 4, 5, 6]
# List a: [1, 2, 'Hi', 3, 4, 5, 6, 'A', 'B']
# List b: ['A', 'B']

# %%
a.extend(s)
a
# Out:
# [1, 2, 'Hi', 3, 4, 5, 6, 'A', 'B', 'C', 'D']

# %%
a.extend(t)
a
# Out:
# [1, 2, 'Hi', 3, 4, 5, 6, 'A', 'B', 'C', 'D', 123, 321]

# %%
#Removing
a=[1,2,3,4,5]
a.remove(1)
a
# Out:
# [2, 3, 4, 5]

# %%
a.pop() #by default it pops out value from last index if index is not given 
a
# Out:
# [2, 3, 4]

# %%
del a[1] #if index is not given and del a is executed whole values are deleted.
a
# Out:
# [2, 4]

# %%
a.clear()
a
# Out:
# []

# %%
fruits=["Apple","Banana","Mango","Litchi","Papaya"]
vegetabes=["Spinach", "Tomato"]
print("Before adding: ", fruits)
fruits.append("Orange")
print("using append: ",fruits)
fruits.insert(0,"Peach")
print("Using insert:", fruits)

fruits.extend(vegetabes)
print("Extending vegetables:", fruits)
# Out:
# Before adding:  ['Apple', 'Banana', 'Mango', 'Litchi', 'Papaya']
# using append:  ['Apple', 'Banana', 'Mango', 'Litchi', 'Papaya', 'Orange']
# Using insert: ['Peach', 'Apple', 'Banana', 'Mango', 'Litchi', 'Papaya', 'Orange']
# Extending vegetables: ['Peach', 'Apple', 'Banana', 'Mango', 'Litchi', 'Papaya', 'Orange', 'Spinach', 'Tomato']

# %%
fruits.remove("Spinach")
print("Using remove: ",fruits)
# Out:
# Using remove:  ['Peach', 'Apple', 'Banana', 'Mango', 'Litchi', 'Papaya', 'Orange']

# %%
fruits.pop()
print("Using pop without index: ",fruits)
# Out:
# Using pop without index:  ['Peach', 'Apple', 'Banana', 'Mango', 'Litchi', 'Papaya']

# %%
a=[123,234,213,345,129,345]
b=["A","b","z","Z"]
a.sort()
a.sort(reverse=True)
a
# Out:
# [345, 345, 234, 213, 129, 123]

# %%
b.sort()
b
b.sort(reverse=True)
b
# Out:
# ['z', 'b', 'Z', 'A']

# %%
#Dictionary
a={"name":"Sonu","age":23,"college":"Virinchi"}
a
# Out:
# {'name': 'Sonu', 'age': 23, 'college': 'Virinchi'}

# %%
print(a.items())
# Out:
# dict_items([('name', 'Sonu'), ('age', 23), ('college', 'Virinchi')])

# %%
print(a.keys())
# Out:
# dict_keys(['name', 'age', 'college'])

# %%
print(a.values())
a
a["name"]
a.get("name")
# Out:
# dict_values(['Sonu', 23, 'Virinchi'])
# 'Sonu'

# %%
#Changing
a["name"]="Lin"
a
# Out:
# {'name': 'Lin', 'age': 23, 'college': 'Virinchi'}

# %%
#Adding
a["faculty"]="IT"
a
# Out:
# {'name': 'Lin', 'age': 23, 'college': 'Virinchi', 'faculty': 'IT'}

# %%
#Update
b={"game":"Football","club":"Coding"}
a.update(b)
a
# Out:
# {'name': 'Lin',
#  'age': 23,
#  'college': 'Virinchi',
#  'faculty': 'IT',
#  'game': 'Football',
#  'club': 'Coding'}

# %%
list1=[1,2]
list1[0]
# Out:
# 1

# %%
#Removing - pop(keys),popitem()
a
a.pop("name")
# Out:
# 'Lin'

# %%
a
# Out:
# {'college': 'Virinchi', 'faculty': 'IT', 'game': 'Football', 'club': 'Coding'}

# %%
a.popitem()
# Out:
# ('club', 'Coding')

# %%
a
# Out:
# {'college': 'Virinchi', 'faculty': 'IT', 'game': 'Football'}

# %%
del a["game"]
a
# Out:
# {'college': 'Virinchi', 'faculty': 'IT'}

# %%
del a
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[104], line 2
#       1 del a
# ----> 2 a
#
# NameError: name 'a' is not defined

# %%
a={"a":1,"b":2}
a.clear()
a
# Out:
# {}

# %%
#Nested List
a=[[1,2],[3,4],[5,6],[7,8]]
a[0][1]=23
a
# Out:
# [[1, 23], [3, 4], [5, 6], [7, 8]]

# %%
#Nested Dictionary
a={"population":{"male":40,"female":30},
   "university":{"male":30,"female":45}
   }
a["population"]["others"]=40
a
# Out:
# {'population': {'male': 40, 'female': 30, 'others': 40},
#  'university': {'male': 30, 'female': 45}}
