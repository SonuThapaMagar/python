# %%
print("Hello") #printing hello world


x=5 #aplha
print(x)

_=5
print(_)

9num=9
print(9num)
# Out:
#   Cell In[3], line 10
#     9num=9
#     ^
# SyntaxError: invalid decimal literal

# %%
9num=9
print(9num)
# Out:
#   Cell In[4], line 1
#     9num=9
#     ^
# SyntaxError: invalid decimal literal

# %%
#camel case
myName="Sonu"
print(myName)
# Out:
# Sonu

# %%
#pascal case
MyName="Sonu"
print(MyName)
# Out:
# Sonu

# %%
#snake case
my_name="Sonu"
print(my_name)
# Out:
# Sonu

# %%
#user input()
name=input("Your name: ")
age=input("Your age: ")
print("Username:", name, "User Age:" ,age)

# %%
#Integer
x=5
y=5.5
z=True
c=1+1j

# %%
print(type(x))
print(type(y))
print(type(z))
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'complex'>

# %%
import sys

print(sys.getsizeof(x))
print(sys.getsizeof(y))
print(sys.getsizeof(z))
print(sys.getsizeof(c))
# Out:
# 28
# 24
# 28
# 32

# %%
text="Hello world"
print(text)
# Out:
# Hello world

# %%
test="Ram said"

# %%
text="Hello world"
print(text[1])
# Out:
# e

# %%
print("Hello")
# Out:
# Hello
