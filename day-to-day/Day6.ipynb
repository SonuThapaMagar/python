# %%
#Loop

x=1
while x<10:
    print(x)
    x+=1
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
print(range(5))

for i in range(1,5):
    print(i)
# Out:
# range(0, 5)
# 1
# 2
# 3
# 4

# %%
x=[1,2,3,4,5]
for i in range(len(x)):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
x=[1,2,3,4,5]
for i in x:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
x=[1,2,3,4,5]
n=0
while n<5:
    if n==2:
        # n+=1
        # continue
        break
    print(f"Index of {x[n]} is {n}")
    n+=1
# Out:
# Index of 1 is 0
# Index of 2 is 1

# %%
#Multiplication table
i=1
while i<4:
    j=1
    while j<=10:
       print(f"{i}x{j}={i*j}")
       j+=1
    i+=1
# Out:
# 1x1=1
# 1x2=2
# 1x3=3
# 1x4=4
# 1x5=5
# 1x6=6
# 1x7=7
# 1x8=8
# 1x9=9
# 1x10=10
# 2x1=2
# 2x2=4
# 2x3=6
# 2x4=8
# 2x5=10
# 2x6=12
# 2x7=14
# 2x8=16
# 2x9=18
# 2x10=20
# 3x1=3
# 3x2=6
# 3x3=9
# 3x4=12
# 3x5=15
# 3x6=18
# 3x7=21
# 3x8=24
# 3x9=27
# 3x10=30

# %%
x=[100,101,200,300]
for i in x:
    if i%10==0:
        print(f"{i} is divisible by 10")
    else:
        print(f"{i} is not divisble by 10")
# Out:
# 100 is divisible by 10
# 101 is not divisble by 10
# 200 is divisible by 10
# 300 is divisible by 10

# %%
x=[100,203,303,400,500,600]
for i in x:
    if i==100:
        print(f"Skipped value is :{i}")
        continue
    if i==500:
        break
    print(i)
# Out:
# Skipped value is :100
# 203
# 303
# 400

# %%
x=[1,2,3,4,3,2,2,1]

for i in x:
    j=0
    for j in x:
        if x[i]+x[j]==5:
            print(f"{x[i]}+{x[j]}={x[i]+x[j]}")
# Out:
# 2+3=5
# 2+3=5
# 2+3=5
# 2+3=5
# 3+2=5
# 3+2=5
# 3+2=5
# 3+2=5
# 3+2=5
# 3+2=5
# 3+2=5
# 3+2=5
# 2+3=5
# 2+3=5
# 2+3=5
# 2+3=5

# %%
#List Comprehension
x=[1,2,3,4,5]
list=[]
for i in x:
    list.append(i**2)
print(list)
# Out:
# [1, 4, 9, 16, 25]

# %%
list=[i**2 for i in x]
print(list)
# Out:
# [1, 4, 9, 16, 25]

# %%
x=[[1,2],[3,4],[5,6]]
y=[]

for i in x:
    print(x)
    for j in i:
        print(j)
        y.append(j)
# Out:
# [[1, 2], [3, 4], [5, 6]]
# 1
# 2
# [[1, 2], [3, 4], [5, 6]]
# 3
# 4
# [[1, 2], [3, 4], [5, 6]]
# 5
# 6

# %%
y
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
x=[[1,2],[3,4],[5,6]]
y=[j for i in x for j in i]
print(y)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
x=[1,2]*2+[3]
x
# Out:
# [1, 2, 1, 2, 3]

# %%
x=-5%2
x
# Out:
# 1

# %%
s={True,False,0,1,2,3,3}
s
# Out:
# {False, True, 2, 3}

# %%
x=0
print((x>0)and(10/x>1))
# Out:
# False

# %%
d={'x':10}
d
# Out:
# {'x': 10}
