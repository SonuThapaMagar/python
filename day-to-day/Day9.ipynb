# %%
#Recursion
def text_rec(text):
    if len(text)==0:
        print("Done")
    else:
        print(text)
        return text_rec(text[:-1])

text_rec("Hello")
# Out:
# Hello
# Hell
# Hel
# He
# H
# Done

# %%
a=lambda x:x**2
a(4)
print(type(a))
# Out:
# <class 'function'>

# %%
def sqrt(n):
    return n**2

l=[1,2,3,4]
a=list(map(sqrt,l))
a
# Out:
# [1, 4, 9, 16]

# %%
l=[1,2,3,4]

r=lambda l:l**2
r=list(map(r,l))
r
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 4
#       1 l=[1,2,3,4]
#       2
#       3 r=lambda l:l**2
# ----> 4 print(r=list(map(r,l)))
#       5 r
#
# TypeError: print() got an unexpected keyword argument 'r'

# %%
def num_rec(a,b):
    if b==1:
        return a 
    else:
        return a+num_rec(a,b-1)
    
num_rec(3,4)
# Out:
# 12

# %%
#Factorial
def factorial(num):
    fact=1
    for i in range(1,num+1):
        fact=fact*i
    return fact
factorial(5)
# Out:
# 120
