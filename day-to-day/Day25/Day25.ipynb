# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\Users\USER\Desktop\python\.venv\Lib\site-packages (3.0.5)
# Requirement already satisfied: numpy>=1.26.0 in c:\Users\USER\Desktop\python\.venv\Lib\site-packages (from pandas) (2.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\Users\USER\Desktop\python\.venv\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\USER\Desktop\python\.venv\Lib\site-packages (from pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in c:\Users\USER\Desktop\python\.venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 3.0.5

# %%
import pandas as pd

marks = pd.Series([80, 90, 75, 88])

print(marks)
# Out:
# 0    80
# 1    90
# 2    75
# 3    88
# dtype: int64

# %%
data = {
    "Name": ["Ram", "Sita", "Hari"],
    "Age": [20, 21, 19],
    "Marks": [80, 90, 75]
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Name  Age  Marks
# 0   Ram   20     80
# 1  Sita   21     90
# 2  Hari   19     75

# %%
#C:/Users/USER/Desktop/python/day-to-day/Day25/penguins_size.csv
file_path="penguins_size.csv"


#To read csv file
df=pd.read_csv(file_path)

# %%
df.head()
# df.head(10)
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
df.tail()
# df.head(10)
# Out:
#     species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 339  Gentoo  Biscoe               NaN              NaN                NaN
# 340  Gentoo  Biscoe              46.8             14.3              215.0
# 341  Gentoo  Biscoe              50.4             15.7              222.0
# 342  Gentoo  Biscoe              45.2             14.8              212.0
# 343  Gentoo  Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# 339          NaN     NaN
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE

# %%
df.shape # 344 rows and 7 columns
# Out:
# (344, 7)

# %%
df.columns # viewing columns
# Out:
# Index(['species', 'island', 'culmen_length_mm', 'culmen_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    str
#  1   island             344 non-null    str
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    str
# dtypes: float64(4), str(3)
# memory usage: 18.9 KB

# %%
df.describe()
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        342.000000       342.000000         342.000000   342.000000
# mean          43.921930        17.151170         200.915205  4201.754386
# std            5.459584         1.974793          14.061714   801.954536
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.225000        15.600000         190.000000  3550.000000
# 50%           44.450000        17.300000         197.000000  4050.000000
# 75%           48.500000        18.700000         213.000000  4750.000000
# max           59.600000        21.500000         231.000000  6300.000000

# %%
df.describe(include="object")
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_8060\702825166.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include="object")
#        species  island   sex
# count      344     344   334
# unique       3       3     3
# top     Adelie  Biscoe  MALE
# freq       152     168   168

# %%
df["species"].unique()
# Out:
# <StringArray>
# ['Adelie', 'Chinstrap', 'Gentoo']
# Length: 3, dtype: str

# %%
df["island"].unique()
df["island"].value_counts()
# Out:
# island
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64

# %%
df["sex"].unique()
# Out:
# <StringArray>
# ['MALE', 'FEMALE', nan, '.']
# Length: 4, dtype: str

# %%
df["sex"].count
# Out:
# <bound method Series.count of 0        MALE
# 1      FEMALE
# 2      FEMALE
# 3         NaN
# 4      FEMALE
#         ...
# 339       NaN
# 340    FEMALE
# 341      MALE
# 342    FEMALE
# 343      MALE
# Name: sex, Length: 344, dtype: str>

# %%
df["sex"].value_counts()
# Out:
# sex
# MALE      168
# FEMALE    165
# .           1
# Name: count, dtype: int64

# %%
# to view dupliate values
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Length: 344, dtype: bool

# %%
df.duplicated().sum()
# df.drop_duplicates() removes duplicate values
# Out:
# np.int64(0)

# %%
df.isna().sum() # is there null values, empty cell?
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
#indexing

# loc =localizer iloc= index localizer
df.loc[1,"culmen_length_mm"]
# Out:
# np.float64(39.5)

# %%
df.loc[1:14,"culmen_length_mm"]
# Out:
# 1     39.5
# 2     40.3
# 3      NaN
# 4     36.7
# 5     39.3
# 6     38.9
# 7     39.2
# 8     34.1
# 9     42.0
# 10    37.8
# 11    37.8
# 12    41.1
# 13    38.6
# 14    34.6
# Name: culmen_length_mm, dtype: float64

# %%
df.iloc[10:20,0:4]
# Out:
#    species     island  culmen_length_mm  culmen_depth_mm
# 10  Adelie  Torgersen              37.8             17.1
# 11  Adelie  Torgersen              37.8             17.3
# 12  Adelie  Torgersen              41.1             17.6
# 13  Adelie  Torgersen              38.6             21.2
# 14  Adelie  Torgersen              34.6             21.1
# 15  Adelie  Torgersen              36.6             17.8
# 16  Adelie  Torgersen              38.7             19.0
# 17  Adelie  Torgersen              42.5             20.7
# 18  Adelie  Torgersen              34.4             18.4
# 19  Adelie  Torgersen              46.0             21.5

# %%
#handling missing values
df.dropna()
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 4    Adelie  Torgersen              36.7             19.3              193.0
# 5    Adelie  Torgersen              39.3             20.6              190.0
# ..      ...        ...               ...              ...                ...
# 338  Gentoo     Biscoe              47.2             13.7              214.0
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# 2         3250.0  FEMALE
# 4         3450.0  FEMALE
# 5         3650.0    MALE
# ..           ...     ...
# 338       4925.0  FEMALE
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE
#
# [334 rows x 7 columns]

# %%
#handling missing values using ==
df["culmen_length_mm"].isna().sum()
# Out:
# np.int64(2)

# %%
df["culmen_length_mm"].mean()
# Out:
# np.float64(43.92192982456141)

# %%
#filling missing values
df["culmen_length_mm"]=df["culmen_length_mm"].fillna(df["culmen_length_mm"].mean()) #single column
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen          39.10000             18.7              181.0
# 1    Adelie  Torgersen          39.50000             17.4              186.0
# 2    Adelie  Torgersen          40.30000             18.0              195.0
# 3    Adelie  Torgersen          43.92193              NaN                NaN
# 4    Adelie  Torgersen          36.70000             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe          43.92193              NaN                NaN
# 340  Gentoo     Biscoe          46.80000             14.3              215.0
# 341  Gentoo     Biscoe          50.40000             15.7              222.0
# 342  Gentoo     Biscoe          45.20000             14.8              212.0
# 343  Gentoo     Biscoe          49.90000             16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# 2         3250.0  FEMALE
# 3            NaN     NaN
# 4         3450.0  FEMALE
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE
#
# [344 rows x 7 columns]

# %%
df.columns
# Out:
# Index(['species', 'island', 'culmen_length_mm', 'culmen_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='str')

# %%
columns=['culmen_depth_mm', 'flipper_length_mm','body_mass_g']
df.columns
# Out:
# Index(['species', 'island', 'culmen_length_mm', 'culmen_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='str')

# %%
df[columns]=df[columns].fillna(df[columns].mean())
df.isna().sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 df[columns]=df[columns].fillna(df[columns].mean())
#       2 df.isna().sum()
#
# File c:\Users\USER\Desktop\python\.venv\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File c:\Users\USER\Desktop\python\.venv\Lib\site-packages\pandas\core\frame.py:14475, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   14471         >>> df.mean(numeric_only=True)
#   14472         a   1.5
#   14473         dtype: float64
#   14474         """
# > 14475         result = super().mean(
#   14476             axis=axis, skipna=skipna, numeric_only=numeric_only, **kwargs
#   14477         )
#   14478         if isinstance(result, Series):
#
# File c:\Users\USER\Desktop\python\.venv\Lib\site-packages\pandas\core\generic.py:11819, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11815         skipna: bool = True,
#   11816         numeric_only: bool = False,
#   11817         **kwargs,
#   11818     ) -> Series | float:
# > 11819         return self._stat_function(
#   11820             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11821         )
#
# File c:\Users\USER\Desktop\python\.venv\Lib\site-packages\pandas\core\generic.py:11773, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11769         nv.validate_func(name, (), kwargs)
#   11770
#   11771         validate_bool_kwarg(skipna, "skipna", none_allowed=False)
#   11772
# > 11773         return self._reduce(
#   11774             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11775         )
#
# File c:\Users\USER\Desktop\python\.venv\Lib\site-packages\pandas\core\frame.py:13635, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   13631             df = df.T
#   13632
#   13633         # After possibly _get_data and transposing, we are now in the
#   13634         #  simple case where we can use BlockManager.reduce
# > 13635         res = df._mgr.reduce(blk_func)
#   13636         out = df._constructor_from_mgr(res, axes=res.axes).iloc[0]
#   13637         out.name = None
#   13638         if out_dtype is not None and out.dtype != "boolean":
#
# File c:\Users\USER\Desktop\python\.venv\Lib\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.reduce(self, func)
#    1691 # If 2D, we assume that we're operating column-wise
#    1692 assert self.ndim == 2
# -> 1694 res_blocks = [blk.reduce(func) for blk in self.blocks]
#    1695 index = default_index(1)  # placeholder
#    1696 # shallow copy self.items not needed because DataFrame._reduce does a getitem
#
# File c:\Users\USER\Desktop\python\.venv\Lib\site-packages\pandas\core\internals\blocks.py:358, in Block.reduce(self, func)
#     352 @final
#     353 def reduce(self, func) -> Block:
#     354     # We will apply the function and reshape the result into a single-row
#     355     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     356     assert self.ndim == 2
# --> 358     result = func(self.values)
#     360     if self.values.ndim == 1:
#     361         res_values = result
#
# File c:\Users\USER\Desktop\python\.venv\Lib\site-packages\pandas\core\frame.py:13565, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   13561                 if not is_1d_only_ea_dtype(values.dtype):
#   13562                     return values._reduce(name, axis=1, skipna=skipna, **kwds)
#   13563                 return values._reduce(name, skipna=skipna, keepdims=True, **kwds)
#   13564             else:
# > 13565                 return op(values, axis=axis, skipna=skipna, **kwds)
#
# File c:\Users\USER\Desktop\python\.venv\Lib\site-packages\pandas\core\nanops.py:149, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     147         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     148 else:
# --> 149     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     151 return result
#
# File c:\Users\USER\Desktop\python\.venv\Lib\site-packages\pandas\core\nanops.py:408, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     405 if datetimelike and mask is None:
#     406     mask = isna(values)
# --> 408 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     410 if datetimelike:
#     411     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File c:\Users\USER\Desktop\python\.venv\Lib\site-packages\pandas\core\nanops.py:713, in nanmean(values, axis, skipna, mask)
#     710     dtype_count = dtype
#     712 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 713 the_sum = values.sum(axis, dtype=dtype_sum)
#     714 the_sum = _ensure_numeric(the_sum)
#     716 if axis is not None and getattr(the_sum, "ndim", False):
#
# File c:\Users\USER\Desktop\python\.venv\Lib\site-packages\numpy\_core\_methods.py:49, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
# ---> 49     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: unsupported operand type(s) for +: 'float' and 'method'

# %%
df.head()
# Out:
#   species     island  culmen_length_mm  \
# 0  Adelie  Torgersen          39.10000
# 1  Adelie  Torgersen          39.50000
# 2  Adelie  Torgersen          40.30000
# 3  Adelie  Torgersen          43.92193
# 4  Adelie  Torgersen          36.70000
#
#                                      culmen_depth_mm  \
# 0                                               18.7
# 1                                               17.4
# 2                                               18.0
# 3  <bound method DataFrame.mean of      culmen_de...
# 4                                               19.3
#
#                                    flipper_length_mm  \
# 0                                              181.0
# 1                                              186.0
# 2                                              195.0
# 3  <bound method DataFrame.mean of      culmen_de...
# 4                                              193.0
#
#                                          body_mass_g     sex
# 0                                             3750.0    MALE
# 1                                             3800.0  FEMALE
# 2                                             3250.0  FEMALE
# 3  <bound method DataFrame.mean of      culmen_de...     NaN
# 4                                             3450.0  FEMALE
