# %%
#Conditional statement
a=5
b=6
c=2

if a>b and a>c:
    print(f"{a}is greater than {b},{c}")
elif b>c:
    print(f"{b} is greater than {a},{c}")
else:
    print(f"{c} is greater than both {a},{b}")
# Out:
# 6 is greater than 5,2
