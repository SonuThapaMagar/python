# %%
a={1,2,3,True,False}
print(a)
print(type(a))
# Out:
# {False, 1, 2, 3}
# <class 'set'>

# %%
a={2,3,True,False}
print(a)
# Out:
# {False, True, 2, 3}

# %%
a.add("Hello")
print(a)
# Out:
# {False, True, 2, 3, 'Hello'}

# %%
print("1" in a)
print(1 in a)
# Out:
# False
# True

# %%
things={"apple","shoes"}
a.update(things)
print(a)
# Out:
# {False, True, 2, 3, 'apple', 'shoes', 'Hello'}

# %%
things={"bag","books"}
a.update(things)
print(a)
# Out:
# {False, True, 2, 3, 'apple', 'bag', 'books', 'shoes', 'Hello'}

# %%
#remove()
a.remove(False)
print("After removing False: ",a)
# Out:
# After removing False:  {True, 2, 3, 'apple', 'bag', 'books', 'shoes', 'Hello'}

# %%
#discard()
a.discard(True)
print("After discarding True: ",a)
a.discard(True) #Again prints value
print(a)
# Out:
# After discarding True:  {3, 'apple', 'bag', 'books', 'shoes', 'Hello'}
# {3, 'apple', 'bag', 'books', 'shoes', 'Hello'}

# %%
#pop()
a.pop()
print("After pop: ",a)
a.pop()
print(a)
# Out:
# After pop:  {'apple', 'bag', 'books', 'shoes', 'Hello'}
# {'bag', 'books', 'shoes', 'Hello'}

# %%
#del 
del a
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 3
#       1 #del
#       2 del a
# ----> 3 a
#
# NameError: name 'a' is not defined

# %%
a={1,2,3,4,5}
a.clear()
a
# Out:
# set()

# %%
# Set Jonits
s1={0,1,2,3,4}
s2={4,5,6,7,8}

print(s1)
print(s2)
s1.union(s2)
# Out:
# {0, 1, 2, 3, 4}
# {4, 5, 6, 7, 8}
# {0, 1, 2, 3, 4, 5, 6, 7, 8}

# %%
# Set Jonits
s1={0,1,2,3,4}
s2={4,5,6,7,8}

print(s1)
print(s2)
print(s1.update(s2))
print(s1| s2)
# Out:
# {0, 1, 2, 3, 4}
# {4, 5, 6, 7, 8}
# None
# {0, 1, 2, 3, 4, 5, 6, 7, 8}

# %%
s1={1,2,3,4}
s2={1,2,3,4,5}

print(s1 | s2)
print(s1)
print(s2)
# Out:
# {1, 2, 3, 4, 5}
# {1, 2, 3, 4}
# {1, 2, 3, 4, 5}

# %%
#intersection
s1={10,32,23,14}
s2={14,2,3,4,5}

print(s1.intersection(s2))
# Out:
# {14}

# %%
print(s1.intersection_update(s2))
# Out:
# None

# %%
print(s1&s2)
# Out:
# {14}

# %%
#difference
s1={90,23,34,45,56}
s2={12,34,45,56,67}

print(s1.difference(s2))
# Out:
# {90, 23}

# %%
print(s1.difference_update(s2))
# Out:
# None

# %%
print(s1-s2)
# Out:
# {90, 23}

# %%
#Symmetric difference
s1={1,2,3,4,5,6}
s2={0,1,3,5,7,9,11}

print(s1.symmetric_difference(s2))
# Out:
# {0, 2, 4, 6, 7, 9, 11}

# %%
s1.symmetric_difference_update(s2)
print(s1)
# Out:
# {0, 2, 4, 6, 7, 9, 11}

# %%
print(s1^s2)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
#Tuple
a=(1,2,3,4,5,"Hi","Hello")
a[0]
a[1:4]
# Out:
# (2, 3, 4)

# %%
a=(1,2,3,4,5,5,5,5,5,"Hi","Hello")
print(a)
# Out:
# (1, 2, 3, 4, 5, 5, 5, 5, 5, 'Hi', 'Hello')

# %%
a[-4:-1]
# Out:
# (4, 5, 'Hi')

# %%
#Converting tuple into list
l1=list(a)
print(l1)
# Out:
# [1, 2, 3, 4, 5, 5, 5, 5, 5, 'Hi', 'Hello']

# %%
l1[0]=11
l1.append(23)
l1
# Out:
# [11, 2, 3, 4, 5, 5, 5, 5, 5, 'Hi', 'Hello', 23]

# %%
l1.remove("Hi")
l1
# Out:
# [11, 2, 3, 4, 5, 5, 5, 5, 5, 'Hello', 23]

# %%
a=tuple(l1)
a
# Out:
# (11, 2, 3, 4, 5, 5, 5, 5, 5, 'Hello', 23)

# %%
#unpacking
a=("Sonu",23,"Python")
name,age,subject=a
print(a)
# Out:
# ('Sonu', 23, 'Python')

# %%
#*rest of values
a=("Sonu","monu","Python")
name,age,subject=a
print(name)
# Out:
# Sonu
# m o n u

# %%
#Left Shit
a=12<<1
print(a)
# Out:
# 24

# %%
print(~12)
# Out:
# -13

# %%
print(12| 18) #OR
print(12& 18) #AND
# Out:
# 30
# 0
