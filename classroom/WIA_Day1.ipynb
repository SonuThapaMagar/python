# %% [markdown]
# ### Basic Syntax

# %%
# comment
print("Heelo world") # printing hello world
# Out:
# Heelo world

# %% [markdown]
# ### Variable Declaration, Naming Convention

# %%
x = 5 #alpha
print(x)
# Out:
# 5

# %%
_ = 5
print(_)
# Out:
# 5

# %%
9num = 9 # invalid decleartion
print(9num)
# Out:
#   File "/tmp/ipykernel_2607/410556065.py", line 1
#     9num = 9
#     ^
# SyntaxError: invalid decimal literal

# %%
if = 5
print(if)
# Out:
#   File "/tmp/ipykernel_2607/2288269952.py", line 1
#     if = 5
#        ^
# SyntaxError: invalid syntax

# %%
num_9 = 9
print(num_9)
# Out:
# 9

# %%
#camel case
myName = "Alice"
#pascal Case
MyName = "Bob"
#Snake Case
my_name = "Marcus"

# %%
# user input input()
name = input("Your Name")
age = input("Yuor age")
print(name)
print("User Name:",name)
print("User age:",age)
print(age)
print(name,age)
# Out:
# Your Nameage
# Yuor age23
# age
# User Name: age
# User age: 23
# 23
# age 23

# %% [markdown]
# ### Datatypes-  Integer, Float, Boolean, Complex

# %%
x  = 5
y = 5.5
z = True
c = 1+1j
print(x,y,z)
print(c)
# Out:
# 5 5.5 True
# (1+1j)

# %%
print(type(x))
print(type(y))
print(type(z))
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'complex'>

# %%
import sys
print(sys.getsizeof(x))
print(sys.getsizeof(y))
print(sys.getsizeof(z))
print(sys.getsizeof(c))
# Out:
# 28
# 24
# 28
# 32

# %% [markdown]
# ### String
#
# 1.   Define, use of escape character
# 2.   Slicing
# 3.   Methods (upper,lower,split,strip,replace(old,new,count), capitalize,find(value), count(value) )
# 4.  f-string

# %%
text = "Hello World"
print(text)
# Out:
# Hello World

# %%
text = "Ram said, \"He is playing\""
print(text)
# Out:
# Ram said, "He is playing"

# %%
text = '''
Hi,
I am learning Python
'''
print(text)
# Out:
# Hi,
# I am learning Python

# %%
text = "Hello World"
print(text[0])
print(text[0:5])
print(text[0:11:2])
print(text[::])
print(text[-11:-1])
print(text[-1:-11:-1])
# Out:
# H
# Hello
# HloWrd
# Hello World
# Hello Worl
# dlroW olle

# %%
text = "Hello World"
print(text.upper())
# Out:
# HELLO WORLD

# %%
print(text.lower())
# Out:
# hello world

# %%
print(len(text))
# Out:
# 11

# %%
text = " hello @ world "
print(len(text))
print(len(text.strip()))
print(text.split())
print(text.split("@"))
print(text.replace("world","there"))
# Out:
# 15
# 13
# ['hello', '@', 'world']
# [' hello ', ' world ']
#  hello @ there
