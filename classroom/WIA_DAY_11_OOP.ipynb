# %% [markdown]
# ### Class Object
# ### Constructor
# ### Class Attribute, Object Attribute

# %%
class MarkerIndustry:
  name = "Camlin"
  height_marker=  12
  radius_marker = 1

# %%
m1 = MarkerIndustry()
m2 = MarkerIndustry()
print(m1)
print(m1.name)
# Out:
# <__main__.MarkerIndustry object at 0x798700e25430>
# Camlin

# %%
class MarkerIndustry:
  def __new__(cls):
    print("Creating Object")
    return super().__new__(cls)

  def __init__(self):
    print('Initalizing object')

# %%
m1 = MarkerIndustry()
print(m1)
# Out:
# Creating Object
# Initalizing object
# <__main__.MarkerIndustry object at 0x798700d28740>

# %%
class MarkerIndustry:
  name= "Camlin"
  height = 12
  radius = 1
  def __init__(self,color):
    self.color = color

  def display(self):
    print (f"Color of marker is :{self.color}")

# %%
m_blue = MarkerIndustry("blue")
print(m_blue)
# Out:
# <__main__.MarkerIndustry object at 0x798700d28050>

# %%
m_blue.display()
# Out:
# Color of marker is :blue

# %%
MarkerIndustry.display(m_blue)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1340/2544102995.py in <cell line: 0>()
# ----> 1 MarkerIndustry.display(m_blue)
#
# TypeError: MarkerIndustry.display() takes 0 positional arguments but 1 was given
